# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 41     |  |
# | :-------------|:-------------|
# | Nina Gumbs| 6552544 |
# | Student naam 2| Student Studienummer 2 |
# | Student naam 3| Student Studienummer 3 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 41    |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 11:00 | Victor |
# | ontwerp-eis berekenen| 11:00 | Nina & Pepper|
# | activiteit 1 | Tijdspanne | hele groep |
# | activiteit 2 | Tijdspanne | hele groep |
# | Evaluatie | 12:00 | ---|
# | Opstelling afmaken | 16:00 | ---|
# | Pauze 1| 12:45 - 13:30 | hele groep |
# | Pauze 2| 14:45 - 15:00 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 3 |
# | hoe lang voor één meting | 5 seconden |
# | verwacht nauwkeurigheid meting | 0.2 |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
f_0 = 2.5
w_0 = 2 *np.pi*f_0
w = np.sqrt(2) * w_0
print(w_0)
# Out:
# 15.707963267948966

# %%
# Voeg hier je plot in.

f_test = np.logspace(-1,1,100)
w_test = 2 *np.pi*f_test
A = np.abs(1/(1-((w_test**2)/((w_0**2)))))

plt.plot(f_test,A)
plt.title("Amplitude overdracht tegenover frequentie vloer (f_0)")
plt.ylabel("A_out/A_in")
plt.xlabel("Frequentie (hz)")
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
delta_x = 9.81 / w_0**2
print(delta_x)
# Out:
# 0.039758432461253344

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().
g = 9.81
C = np.linspace(0,100,100)
m = delta_x*C/g
plt.plot(m,C, label = "1*delta_x")
plt.plot(2*m,C, label = "2*delta_x")
plt.plot(5*m,C, label = "5*delta_x")
plt.xlabel("massa(kg)")
plt.ylabel("veerconstante(N/m^2)")
plt.title("Massa tegen over veerconstante bij verschillende delta x")
plt.legend()
plt.savefig('massa_veerconstante.png')

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - Massa verhogen
# - Veerconstante verlagen
#
# Delta x = mg/C. Door m te verhogen wordt delta x hoger. Door C te verlagen, wordt delta x hoger
# Als groep gaan we mikken op een $\Delta x$ van: 8 cm

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Schets1.jpeg" width="400" style="transform: rotate(90deg)">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 4 cm
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Nee
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **Voeg hier je antwoord in**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Voeg hier je antwoord in**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
# Nee
#
# **Voeg hier je antwoord in.**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %% [markdown]
# ##### schets opstelling:
# <img src="schets.jpeg" width="400" style="transform: rotate(0deg)">

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 4 cm
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Ja, gemeten delta x is 7 cm
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# 14 cm
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Ja
#
# ### Gaat je ontwerp dus voldoen aan de eis?
# Ja
#
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.

delta_x_nieuw = 0.07
w_0_nieuw = np.sqrt(9.81 / delta_x_nieuw)
A_nieuw = np.abs(1/(1-((w_test**2)/(w_0_nieuw**2))))

plt.plot(f_test, A, label='grens ontwerp ei')
plt.plot(f_test, A_nieuw, label='ons ontwerp')
plt.title("Amplitude overdracht tegenover frequentie vloer (f_0)")
plt.ylabel("A_out/A_in")
plt.xlabel("Frequentie (Hz)")
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.
f_metingen = np.array([6,4.5,5,6.2,7.6,4,2,2.5,1.1,1.6])
A_metingen = 1/np.array([5,2,2.8,6,14,1.5,0.5,0.3,0.5,0.07])

x_error = np.array([1.5,1,2,1.5,3,1,0.3,2,0.2,0.1])
y_error = 0.1

plt.plot(f_test, A, label='gegeven data')
plt.plot(f_test, A_nieuw, label='ons ontwerp')
plt.plot(f_metingen,A_metingen, 'o', label = 'metingen')
plt.errorbar(f_metingen,A_metingen, xerr = x_error , yerr = y_error, linestyle="", label = 'metingen')
plt.title("Amplitude overdracht tegenover frequentie vloer (f_0)")
plt.ylabel("Verhouding amplitude")
plt.xlabel("Frequentie (Hz)")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.savefig('metingen.png')

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# Op basis van een differentiaal vergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp.

# %%
# Voeg hier je plots n.
f_metingen = np.array([6,4.5,5,6.2,7.6,4,2,2.5,1.1,1.6])
A_metingen = 1/np.array([5,2,2.8,6,14,1.5,0.5,0.3,0.5,0.07])

x_error = np.array([1.5,1,2,1.5,3,1,0.3,2,0.2,0.1])
y_error = 0.1

plt.plot(f_test, A, label='gegeven data')
plt.plot(f_test, A_nieuw, label='ons ontwerp')
plt.plot(f_metingen,A_metingen, 'o', label = 'metingen')
plt.errorbar(f_metingen,A_metingen, xerr = x_error , yerr = y_error, linestyle="", label = 'metingen')
plt.title("Amplitude overdracht tegenover frequentie vloer (f_0)")
plt.ylabel("Verhouding amplitude")
plt.xlabel("Frequentie (Hz)")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.savefig('metingen.png')

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen.
# <img src="massa_veerconstante.png" width="400">
