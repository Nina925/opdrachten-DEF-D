# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: 14    |  |
# | :-------------|:-------------|
# | Nina Gumbs| 6552544 |
# | Simon Baur| 6217788 |
# | Koen Gerkes 3| 6495311 3 |
# | Planning Groep: 14     |Tijdstip / Tijdspanne  |
# |---|---|
# | Condensator ontworpen | 12:30 |
# | Sensor ontworpen |16:00 |
# | groep aanwezig 1| 10:35 |
# | groep aanwezig 2| 10:35 |
# | Pauze 1| 12:30-13:45 |
# | Pauze 2| 14:30-14:45 |

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="schets.png" alt="schets student 1" width="400"/>

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
import numpy as np

epsilon0 = 8.854e-12  # 

def berekening_condensator(epsilonr,A,d):
    epsilonr = np.array(epsilonr)
    A = np.array(A)
    d = np.array(d)
    
    return (epsilon0 * epsilonr * A) / d
    
epsilonr_values = [3]
A_values = [0.01]  
d_values = [0.001]
    
    
# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = berekening_condensator(epsilonr_values, A_values, d_values)
C_pF = C * 1e12

print(f"Berekende capaciteit plaatcondensator groep 14 is {C_pF[0]:.1f} pF")
# Out:
# Berekende capaciteit plaatcondensator groep 14 is 265.6 pF

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
#
# <img src="scope.jpeg" alt="scope" width="400"/>
# <img src="condensator.jpeg" alt="condensator" width="400"/>

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 14| 265.6 pF | 1.33 V| 1.3 V |259 pF |

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# <img src="sensoren1.jpeg" alt="drie schetsen" width="400"/>

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Pas deze tekst aan: Wij gaan een sensor maken die gewicht meet.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# <img src="weegschaal.jpeg" alt="uitgewerkte schets" width="400"/>

# %%
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
import matplotlib.pyplot as plt

d = np.array([0.027,0.024,0.021,0.017])
C2 = berekening_condensator(epsilonr_values, A_values, d) *1e12
gewicht = np.array([0,0.250,0.450,1])
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.title("Verwachte grafiek van de sensor") 
plt.xlabel('Gewicht (kg)') 
plt.ylabel('Capaciteit (pF)')

print(C2)
# Out:
# [ 9.83777778 11.0675     12.64857143 15.62470588]

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minimale capaciteit| 11.1 |110 |
# | gemiddelde capaciteit| 12.6 |125|
# | maximale capaciteit| 15.6 |160|

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# <img src="meting1.jpeg" alt="meting 1" width="400"/>
# <img src="scope1.jpeg" alt="scope 1" width="400"/>
# <img src="meting2.jpeg" alt="meting 2" width="400"/>
# <img src="scope2.jpeg" alt="scope 2" width="400"/>

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
# Gemeten Arduino data (omgezet naar kg)
gewicht1 = np.array([539.2,999.2,451.2,911.2,378.2,838.2,271.7,731.7]) * 1e-3  # kg
capaciteit1 = np.array([10.6,11.7,10.0,11.0,9.9,10.8,9.7,10.6])                 # pF

# Sorteer gemeten data op gewicht
sort_index = np.argsort(gewicht1)
gewicht1_sorted = gewicht1[sort_index]
capaciteit1_sorted = capaciteit1[sort_index]           

coeffs = np.polyfit(gewicht1_sorted, capaciteit1_sorted, 1)
fit_line = np.polyval(coeffs, gewicht1_sorted)
print(f"Lineaire fit: y = {coeffs[0]:.2f}*x + {coeffs[1]:.2f}")

# Plot
plt.figure(figsize=(7,5))
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.plot(gewicht1_sorted, capaciteit1_sorted, marker='s', label='Gemeten capaciteit')
plt.plot(gewicht1_sorted, fit_line, '-', label=f'Lineaire fit: y={coeffs[0]:.2f}*x + {coeffs[1]:.2f}')

# Labels, titel en legend
plt.xlabel('Gewicht (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek: Gewicht versus Capaciteit')
plt.legend()
plt.grid(True)
# Out:
# Lineaire fit: y = 2.34*x + 9.04

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * verbetering 1: Spons
# Spons kan vervormen na veel gebruik
# * verbetering 2: Tape
# Meer tape voor stabieltijd

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# <img src="opstelling.jpeg" alt="opstelling" width="400"/>

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij

gewicht2 = np.array([920.3,1380.3,760,1220,700,1160,625,1085])*1e-3
capaciteit2 = np.array([11.3,13,10.8,12.3,10.8,12.4,10.7,12.0])

#sorteren
sort_index = np.argsort(gewicht2)
gewicht2_sorted = gewicht2[sort_index]
capaciteit2_sorted = capaciteit2[sort_index]

coeffs2 = np.polyfit(gewicht2_sorted, capaciteit2_sorted, 1)
fit_line2 = np.polyval(coeffs2, gewicht2_sorted)

#plotten  
plt.plot(gewicht2_sorted, capaciteit2_sorted, marker='o', linestyle='-', label='Gemeten data')
plt.plot(gewicht2_sorted, fit_line2, '-', label=f'Lineaire fit: y={coeffs2[0]:.2f}*x + {coeffs2[1]:.2f}')
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.xlabel('Gewicht (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek: Gewicht versus Capaciteit')
plt.legend()

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# De sensor is niet geschikt om gewicht in een range van 0.250 kg tot 1 kg te meten, vanwege de kleine range in de metingen. In de metingen is maar een verschil van 3 pF. Wel is er een duidelijk verband tussen het gewicht en de gemeten capaciteit in deze kleine range in capaciteit. Na de verbetering voor een stabiele opstelling, werd het verband duidelijker. De verwachte waardes liggen hoger dan de gemeten waardes. Dit komt door de kleine range van meting en omdat omdat de dikte een onnauwkeurige manier is om de capaciteit te bepalen. De dikte kan varieren van plek tot plek en er was geen nauwkeurig meetinstrument beschikbaar. Uit dit blijkt dat de vlakke plaat formule niet genoeg is voor onze sensor.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.
# #Opdracht 1
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="schets.png" alt="schets student 1" width="400"/>
#
# #Opdracht 2
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# <img src="sensoren1.jpeg" alt="drie schetsen" width="400"/>

# %%
#Opdracht 4
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
import matplotlib.pyplot as plt

d = np.array([0.027,0.024,0.021,0.017])
C2 = berekening_condensator(epsilonr_values, A_values, d) *1e12
gewicht = np.array([0,0.250,0.450,1])
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.title("Verwachte grafiek van de sensor") 
plt.xlabel('Gewicht (kg)') 
plt.ylabel('Capaciteit (pF)')

print(C2)
# Out:
# [ 9.83777778 11.0675     12.64857143 15.62470588]

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen

# %% [markdown]
# #Opgave 6
# <img src="meting1.jpeg" alt="meting 1" width="400"/>
# <img src="scope1.jpeg" alt="scope 1" width="400"/>
# <img src="meting2.jpeg" alt="meting 2" width="400"/>
# <img src="scope2.jpeg" alt="scope 2" width="400"/>

# %%
#Opgave 7
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
# Gemeten Arduino data (omgezet naar kg)
gewicht1 = np.array([539.2,999.2,451.2,911.2,378.2,838.2,271.7,731.7]) * 1e-3  # kg
capaciteit1 = np.array([10.6,11.7,10.0,11.0,9.9,10.8,9.7,10.6])                 # pF

# Sorteer gemeten data op gewicht
sort_index = np.argsort(gewicht1)
gewicht1_sorted = gewicht1[sort_index]
capaciteit1_sorted = capaciteit1[sort_index]           

coeffs = np.polyfit(gewicht1_sorted, capaciteit1_sorted, 1)
fit_line = np.polyval(coeffs, gewicht1_sorted)
print(f"Lineaire fit: y = {coeffs[0]:.2f}*x + {coeffs[1]:.2f}")

# Plot
plt.figure(figsize=(7,5))
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.plot(gewicht1_sorted, capaciteit1_sorted, marker='s', label='Gemeten capaciteit')
plt.plot(gewicht1_sorted, fit_line, '-', label=f'Lineaire fit: y={coeffs[0]:.2f}*x + {coeffs[1]:.2f}')

# Labels, titel en legend
plt.xlabel('Gewicht (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek: Gewicht versus Capaciteit')
plt.legend()
plt.grid(True)
# Out:
# Lineaire fit: y = 2.34*x + 9.04

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %%
#Opdracht 7
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
# Gemeten Arduino data (omgezet naar kg)
gewicht1 = np.array([539.2,999.2,451.2,911.2,378.2,838.2,271.7,731.7]) * 1e-3  # kg
capaciteit1 = np.array([10.6,11.7,10.0,11.0,9.9,10.8,9.7,10.6])                 # pF

# Sorteer gemeten data op gewicht
sort_index = np.argsort(gewicht1)
gewicht1_sorted = gewicht1[sort_index]
capaciteit1_sorted = capaciteit1[sort_index]           

coeffs = np.polyfit(gewicht1_sorted, capaciteit1_sorted, 1)
fit_line = np.polyval(coeffs, gewicht1_sorted)
print(f"Lineaire fit: y = {coeffs[0]:.2f}*x + {coeffs[1]:.2f}")

# Plot
plt.figure(figsize=(7,5))
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.plot(gewicht1_sorted, capaciteit1_sorted, marker='s', label='Gemeten capaciteit')
plt.plot(gewicht1_sorted, fit_line, '-', label=f'Lineaire fit: y={coeffs[0]:.2f}*x + {coeffs[1]:.2f}')

# Labels, titel en legend
plt.xlabel('Gewicht (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek: Gewicht versus Capaciteit')
plt.legend()
plt.grid(True)
# Out:
# Lineaire fit: y = 2.34*x + 9.04

# %%
#Opdracht 9
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij

gewicht2 = np.array([920.3,1380.3,760,1220,700,1160,625,1085])*1e-3
capaciteit2 = np.array([11.3,13,10.8,12.3,10.8,12.4,10.7,12.0])

#sorteren
sort_index = np.argsort(gewicht2)
gewicht2_sorted = gewicht2[sort_index]
capaciteit2_sorted = capaciteit2[sort_index]

coeffs2 = np.polyfit(gewicht2_sorted, capaciteit2_sorted, 1)
fit_line2 = np.polyval(coeffs2, gewicht2_sorted)

#plotten  
plt.plot(gewicht2_sorted, capaciteit2_sorted, marker='o', linestyle='-', label='Gemeten data')
plt.plot(gewicht2_sorted, fit_line2, '-', label=f'Lineaire fit: y={coeffs2[0]:.2f}*x + {coeffs2[1]:.2f}')
plt.xlabel('Gewicht (kg)')
plt.ylabel('Capaciteit (pF)')
plt.title('Kalibratiegrafiek: Gewicht versus Capaciteit')
plt.legend()

# %%
#Opgave 4: 
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
import matplotlib.pyplot as plt

d = np.array([0.027,0.024,0.021,0.017])
C2 = berekening_condensator(epsilonr_values, A_values, d) *1e12
gewicht = np.array([0,0.250,0.450,1])
plt.plot(gewicht,C2, marker = 'o', linestyle='-')
plt.title("Verwachte grafiek van de sensor") 
plt.xlabel('Gewicht (kg)') 
plt.ylabel('Capaciteit (pF)')

print(C2)
# Out:
# [ 9.83777778 11.0675     12.64857143 15.62470588]

# %% [markdown]
# #Opdracht 10
# De sensor is niet geschikt om gewicht in een range van 0.250 kg tot 1 kg te meten, vanwege de kleine range in de metingen. In de metingen is maar een verschil van 3 pF. Wel is er een duidelijk verband tussen het gewicht en de gemeten capaciteit in deze kleine range in capaciteit. Na de verbetering voor een stabiele opstelling, werd het verband duidelijker. De verwachte waardes liggen hoger dan de gemeten waardes. Dit komt door de kleine range van meting en omdat omdat de dikte een onnauwkeurige manier is om de capaciteit te bepalen. De dikte kan varieren van plek tot plek en er was geen nauwkeurig meetinstrument beschikbaar. Uit dit blijkt dat de vlakke plaat formule niet genoeg is voor onze sensor.
